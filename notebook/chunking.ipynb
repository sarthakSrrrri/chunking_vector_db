# %%
from pathlib import Path
from pypdf import PdfReader

# %%
DATA_PATH = Path("../data/pdfs/structured/annual_report_2025.pdf")
print("Path Exist", path.exists())
print("File Exist : " , path.is_file())
# print("Is file : " , path.resolve())

if not path.exists():
    raise FileNotFoundError("File not found" , path.resolve())

pdf_reader = PdfReader(DATA_PATH)
chunked_text = ""

for page in pdf_reader.pages:
    page_text = page.extract_text()
    if page_text:
        chunked_text = chunked_text + page_text + "\n"

print(f"Page length : " , len(pdf_reader.pages))
print(f"Page length : " , len(chunked_text))
# Out:
# Path Exist True
# File Exist :  True
# Page length :  14
# Page length :  0
